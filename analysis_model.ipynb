# %%
! pip install -r requirements.txt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")
sns.set(style="whitegrid")

# %%
df = pd.read_csv(r"AIML Dataset.csv")
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 11 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   step            1048575 non-null  int64
#  1   type            1048575 non-null  str
#  2   amount          1048575 non-null  float64
#  3   nameOrig        1048575 non-null  str
#  4   oldbalanceOrg   1048575 non-null  float64
#  5   newbalanceOrig  1048575 non-null  float64
#  6   nameDest        1048575 non-null  str
#  7   oldbalanceDest  1048575 non-null  float64
#  8   newbalanceDest  1048575 non-null  float64
#  9   isFraud         1048575 non-null  int64
#  10  isFlaggedFraud  1048575 non-null  int64
# dtypes: float64(5), int64(3), str(3)
# memory usage: 116.4 MB

# %% [markdown]
# ### o - is not fraud
# ### 1 - is fraud

# %%
df["isFraud"].value_counts()
# Out:
# isFraud
# 0    1047433
# 1       1142
# Name: count, dtype: int64

# %%
df["isFlaggedFraud"].value_counts()
# Out:
# isFlaggedFraud
# 0    1048575
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df.shape
# Out:
# (1048575, 11)

# %% [markdown]
# ## What percentage of the total transactions are fraudulent?

# %%
round((df["isFraud"].value_counts()[1] / df.shape[0]) * 100,2)
# Out:
# np.float64(0.11)

# %% [markdown]
# #### Fraud percentage = 0.11%
#
# This means only 0.11% of all transactions are fraud, while 99.89% are not fraud.

# %%
sd = df["type"].value_counts().plot(kind="bar", title="Transaction Type", color="skyblue")
plt.xlabel("Transaction Type")
plt.ylabel("Count")

labels = [f"{int(n):,}"for n in sd.containers[0].datavalues]
sd.bar_label(sd.containers[0],labels=labels)

# plt.show()
# Out:
# [Text(0, 0, '373,641'),
#  Text(0, 0, '353,873'),
#  Text(0, 0, '227,130'),
#  Text(0, 0, '86,753'),
#  Text(0, 0, '7,178')]

# %%
# fraud_by_type

# %%
fraud_by_type = df.groupby("type")["isFraud"].mean()
pd = fraud_by_type.plot(kind="bar", title="Fraud Rate by Type", color="salmon")
plt.ylabel("fraud Rate")

labels = [f"{round(i,5):,}" for i in pd.containers[0].datavalues]
pd.bar_label(pd.containers[0], labels=labels)
# Out:
# [Text(0, 0, '0.0'),
#  Text(0, 0, '0.00155'),
#  Text(0, 0, '0.0'),
#  Text(0, 0, '0.0'),
#  Text(0, 0, '0.0065')]

# %%
df.groupby("type")["isFraud"].mean()
# Out:
# type
# CASH_IN     0.000000
# CASH_OUT    0.001547
# DEBIT       0.000000
# PAYMENT     0.000000
# TRANSFER    0.006501
# Name: isFraud, dtype: float64

# %%
df["amount"].describe().astype(int)
# Out:
# count     1048575
# mean       158666
# std        264940
# min             0
# 25%         12149
# 50%         76343
# 75%        213761
# max      10000000
# Name: amount, dtype: int64

# %%
df.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  1.048575e+06  1.048575e+06   1.048575e+06    1.048575e+06
# mean   2.696617e+01  1.586670e+05   8.740095e+05    8.938089e+05
# std    1.562325e+01  2.649409e+05   2.971751e+06    3.008271e+06
# min    1.000000e+00  1.000000e-01   0.000000e+00    0.000000e+00
# 25%    1.500000e+01  1.214907e+04   0.000000e+00    0.000000e+00
# 50%    2.000000e+01  7.634333e+04   1.600200e+04    0.000000e+00
# 75%    3.900000e+01  2.137619e+05   1.366420e+05    1.746000e+05
# max    9.500000e+01  1.000000e+07   3.890000e+07    3.890000e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    1.048575e+06    1.048575e+06  1.048575e+06       1048575.0
# mean     9.781600e+05    1.114198e+06  1.089097e-03             0.0
# std      2.296780e+06    2.416593e+06  3.298351e-02             0.0
# min      0.000000e+00    0.000000e+00  0.000000e+00             0.0
# ...

# %%
sns.histplot(np.log1p(df["amount"]), bins=100, kde=True, color="Green")
plt.title("Transaction Amount Distribution (log scale)")
plt.xlabel("Log(Amount + 1)")
plt.show()

# %%
sns.boxplot(data=df[df["amount"] < 50000], x = "isFraud", y="amount")
plt.title("Amount vs isFraud (Filtered under 50K)")
plt.show()

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %% [markdown]
# ### Feature Engineering

# %%
df["balanceDiffOrig"] = df["oldbalanceOrg"] - df["newbalanceOrig"]
df["balanceDiffDest"] = df["newbalanceDest"] - df["oldbalanceDest"]

# %%
(df['balanceDiffOrig'] < 0).sum()
# Out:
# np.int64(221805)

# %%
(df['balanceDiffOrig'] > 0).sum()
# Out:
# np.int64(482134)

# %%
(df['balanceDiffDest'] < 0).sum()
# Out:
# np.int64(203566)

# %%
(df['balanceDiffDest'] > 0).sum()
# Out:
# np.int64(465925)

# %%
fraud_per_step = df[df["isFraud"] == 1]["step"].value_counts().sort_index()
plt.plot(fraud_per_step.index, fraud_per_step.values, label="Fraud Per Step")
plt.xlabel("Step (Time)")
plt.ylabel("Number of Frauds")
plt.title("Fraude Over Time")
plt.grid(True)
plt.show()

# %%
df.drop(columns="step", inplace=True)

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balanceDiffOrig  balanceDiffDest
# 0          9839.64              0.0
# 1          1864.28              0.0
# ...

# %%
top_senders = df["nameOrig"].value_counts().head(10)
top_senders
# Out:
# nameOrig
# C918584437     2
# C1154275164    2
# C2012831257    2
# C40561022      2
# C199116739     2
# C1473405499    2
# C44568807      2
# C1077087409    2
# C638093446     2
# C2045948937    2
# Name: count, dtype: int64

# %%
top_receivers = df["nameDest"].value_counts().head(10)
top_receivers
# Out:
# nameDest
# C985934102     98
# C1286084959    96
# C1590550415    89
# C248609774     88
# C665576141     87
# C2083562754    86
# C977993101     82
# C1360767589    81
# C451111351     80
# C97730845      79
# Name: count, dtype: int64

# %%
fraud_users = df[df["isFraud"] == 1]["nameOrig"].value_counts().head(10)
fraud_users
# Out:
# nameOrig
# C1305486145    1
# C840083671     1
# C1420196421    1
# C2101527076    1
# C137533655     1
# C1118430673    1
# C749981943     1
# C1334405552    1
# C467632528     1
# C1364127192    1
# Name: count, dtype: int64

# %%
fraud_types = df[df["type"].isin(["TRANSFER","CASH_OUT"])]
fraud_types["type"].value_counts()
# Out:
# type
# CASH_OUT    373641
# TRANSFER     86753
# Name: count, dtype: int64

# %%
FD = sns.countplot(data=fraud_types, x="type", hue="isFraud")
plt.title("Fraud Distribution in Transfer & Case_out")


labels = [f"{int(i):,}" for i in FD.containers[0].datavalues]
FD.bar_label(FD.containers[0], labels=labels)

plt.show()

# %%
corr = df[["amount","oldbalanceOrg","newbalanceOrig","oldbalanceDest","newbalanceDest","isFraud"]].corr()
corr
# Out:
#                   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# amount          1.000000       0.004864       -0.001133        0.215558
# oldbalanceOrg   0.004864       1.000000        0.999047        0.093305
# newbalanceOrig -0.001133       0.999047        1.000000        0.095182
# oldbalanceDest  0.215558       0.093305        0.095182        1.000000
# newbalanceDest  0.311936       0.064049        0.063725        0.978403
# isFraud         0.128862       0.003829       -0.009438       -0.007552
#
#                 newbalanceDest   isFraud
# amount                0.311936  0.128862
# oldbalanceOrg         0.064049  0.003829
# newbalanceOrig        0.063725 -0.009438
# oldbalanceDest        0.978403 -0.007552
# newbalanceDest        1.000000 -0.000495
# isFraud              -0.000495  1.000000

# %%
sns.heatmap(corr,annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation matrix")
plt.show()

# %%
zero_after_transfer = df[
    (df["oldbalanceOrg"] > 0) &
    (df["newbalanceOrig"] == 0) &
    (df["type"].isin(["TRANSFER","CASH_OUT"]))
]

# %%
len(zero_after_transfer)
# Out:
# 192858

# %%
zero_after_transfer.head()
# Out:
#         type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2   TRANSFER     181.00  C1305486145          181.0             0.0
# 3   CASH_OUT     181.00   C840083671          181.0             0.0
# 15  CASH_OUT  229133.94   C905080434        15325.0             0.0
# 19  TRANSFER  215310.30  C1670993182          705.0             0.0
# 24  TRANSFER  311685.89  C1984094095        10835.0             0.0
#
#        nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 2    C553264065             0.0            0.00        1               0
# 3     C38997010         21182.0            0.00        1               0
# 15   C476402209          5083.0        51513.44        0               0
# 19  C1100439041         22425.0            0.00        0               0
# 24   C932583850          6267.0      2719172.89        0               0
#
#     balanceDiffOrig  balanceDiffDest
# 2             181.0             0.00
# 3             181.0        -21182.00
# ...

# %%
df["isFraud"].value_counts()
# Out:
# isFraud
# 0    1047433
# 1       1142
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balanceDiffOrig  balanceDiffDest
# 0          9839.64              0.0
# 1          1864.28              0.0
# ...

# %%
df_model = df.drop(["nameOrig","nameDest","isFlaggedFraud"], axis=1)
df_model
# Out:
#              type     amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0         PAYMENT    9839.64      170136.00       160296.36            0.00
# 1         PAYMENT    1864.28       21249.00        19384.72            0.00
# 2        TRANSFER     181.00         181.00            0.00            0.00
# 3        CASH_OUT     181.00         181.00            0.00        21182.00
# 4         PAYMENT   11668.14       41554.00        29885.86            0.00
# ...           ...        ...            ...             ...             ...
# 1048570  CASH_OUT  132557.35      479803.00       347245.65       484329.37
# 1048571   PAYMENT    9917.36       90545.00        80627.64            0.00
# 1048572   PAYMENT   14140.05       20545.00         6404.95            0.00
# 1048573   PAYMENT   10020.05       90605.00        80584.95            0.00
# 1048574   PAYMENT   11450.03       80584.95        69134.92            0.00
#
# ...

# %%
categorical = ["type"]
numeric = ["amount", "oldbalanceOrg", "newbalanceOrig", "oldbalanceDest", "newbalanceDest"]

# %%
y = df_model["isFraud"]
X = df_model.drop("isFraud", axis=1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.3, stratify=y)

# %%
preprocessor = ColumnTransformer(
    transformers = [
        ("num", StandardScaler(), numeric),
        ("cat", OneHotEncoder(drop="first"), categorical)
    ],
    remainder="drop"
)

# %%
Pipeline = Pipeline([
    ("prep", preprocessor),
    ("clf", LogisticRegression(class_weight="balanced", max_iter=1000))
])

# %%
Pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['type'])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred = Pipeline.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96    314230
#            1       0.01      0.97      0.03       343
#
#     accuracy                           0.93    314573
#    macro avg       0.51      0.95      0.50    314573
# weighted avg       1.00      0.93      0.96    314573

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[292060,  22170],
#        [    12,    331]])

# %%
Pipeline.score(X_test, y_test)
# Out:
# 0.9294853658769189

# %%
import joblib

joblib.dump(Pipeline,"fraud_detection_pipline.pkl")
# Out:
# ['fraud_detection_pipline.pkl']
